# %% [markdown]
# # Scraping

# %%
# Scraping web google play store for app reviews and ratings with google_play_scraper library dan app store scraper library

from app_store_scraper import AppStore
from google_play_scraper import app, reviews_all, Sort
import pandas as pd
import time

# %% [markdown]
# # Scraping google play store

# %%
# Define the app id dana dompet digital
app_id_dana = 'id.dana'

# Get the app details
result = reviews_all(
    app_id=app_id_dana,
    lang='id',
    count=1000,
    sort=Sort.NEWEST,
    filter_score_with=None
)

# %%
# Create a dataframe
data_google_play = pd.DataFrame(result)

# %%
data_google_play.tail()
# Out:
#                                  reviewId         userName  \
# 592  35c8451b-09a9-45f2-830e-64d041a00706         Andi Wae
# 593  3d670a39-4c34-44c4-ab76-a731d7142088         Joni Bae
# 594  4f30bfce-7e90-4af4-8e9d-f1a3549f7529    Alfan Wahyudi
# 595  c4543c4a-cf61-47dc-bda0-641a9e49d215       Syukri Adi
# 596  9e63cfa3-f3ef-433a-873d-be58b18bdd26  Yoyok Sariyanto
#
#                                              userImage  \
# 592  https://play-lh.googleusercontent.com/a-/ALV-U...
# 593  https://play-lh.googleusercontent.com/a/ACg8oc...
# 594  https://play-lh.googleusercontent.com/a-/ALV-U...
# 595  https://play-lh.googleusercontent.com/a/ACg8oc...
# 596  https://play-lh.googleusercontent.com/a/ACg8oc...
#
#                                                content  score  thumbsUpCount  \
# 592  Gimana caranya masuk kalu kartu no nya udah ga...      4              0
# 593  Saya kecewa menggunakan dana masalah refound a...      1              0
# ...

# %%
# Save the data to csv
data_google_play.to_csv('Dataset/data_google_play.csv', index=False)

# %% [markdown]
# # Scraping data app store

# %%
# Define the app id dana dompet digital
app_id_dana_appstore = 1437123008

# Get the app details
g_app = reviews_all(
    app_id=app_id_dana_appstore,
    sleep_milliseconds=0,
    lang='id',
    sort=Sort.NEWEST
)

a_reviews = AppStore(country="id", app_name="dana-dompet-digital", app_id=app_id_dana_appstore)
a_reviews.review(how_many=1000)
# Out:
# 2024-05-06 21:39:26,382 [INFO] Base - Initialised: AppStore('id', 'dana-dompet-digital', 1437123008)
# 2024-05-06 21:39:26,383 [INFO] Base - Ready to fetch reviews from: https://apps.apple.com/id/app/dana-dompet-digital/id1437123008
# 2024-05-06 21:39:31,900 [INFO] Base - [id:1437123008] Fetched 160 reviews (160 fetched in total)
# 2024-05-06 21:39:37,690 [INFO] Base - [id:1437123008] Fetched 320 reviews (320 fetched in total)
# 2024-05-06 21:39:43,824 [INFO] Base - [id:1437123008] Fetched 500 reviews (500 fetched in total)
# 2024-05-06 21:39:49,886 [INFO] Base - [id:1437123008] Fetched 680 reviews (680 fetched in total)
# 2024-05-06 21:39:56,166 [INFO] Base - [id:1437123008] Fetched 860 reviews (860 fetched in total)
# 2024-05-06 21:40:00,867 [INFO] Base - [id:1437123008] Fetched 1000 reviews (1000 fetched in total)

# %%
# Convert the result to dataframe
data_app_store = pd.DataFrame(a_reviews.reviews)

# %%
data_app_store.head()
# Out:
#                  date                                             review  \
# 0 2019-08-31 10:35:48     Sangat membantu cukup praktis dan banyak promo
# 1 2020-12-20 01:49:48  Semua proses transaksi sangat smooth. \nUtk pe...
# 2 2019-10-06 06:06:16  Kenapa saya kasih bintang 1? Ya mngkin ada kes...
# 3 2021-03-07 22:34:10  Dih najis kalau mau membayar kasih notif apa k...
# 4 2019-10-08 15:57:08  sudah 2hr TOPUP dana blm masuk saldo, makin ke...
#
#    rating  isEdited                             title            userName  \
# 0       5     False                              upik              Upik.R
# 1       5     False                  Praktis dan Aman  Moonshine and Coke
# 2       1     False      Kecewa dengan pelayanan dana            kaka0996
# 3       1     False                              Gblk      joeeeee harris
# 4       5     False  TOPUP SALDO DANA MAKIN GAK JELAS              synori
#
#                                    developerResponse
# ...

# %%
# Save the data to csv
data_app_store.to_csv('Dataset/data_app_store.csv', index=False)
